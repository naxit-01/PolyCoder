# %% [markdown]
# def binarySearch(arr, left, right, x):
# &nbsp;&nbsp;&nbsp;&nbsp;    mid = (left +

# %%
def binarySearch(arr, left, right, x):
    mid = (left + right) // 2
    if arr[mid] > x:
        return binarySearch(arr, left, mid - 1, x)
    elif arr[mid] < x:
        return binarySearch(arr, mid + 1, right, x)
    else:

def binarySearch(arr, left, right, x):
    mid = (left + right) // 2
    if arr[mid] > x:
        return binarySearch(arr, left, mid - 1, x)
    if arr[mid] < x:
        return binarySearch(arr, mid + 1, right, x)
    return mid

def binarySearch(arr, left, right, x):
    mid = (left + right) // 2
    if arr[mid] > x:
        return binarySearch(arr, left, mid - 1, x)
    elif arr[mid] < x:
        return binarySearch(arr, mid + 1, right, x)
    return mid

# %% [markdown]
# def countnumbers(a,b):

# %%
def countnumbers(a,b):
                                                                                           
def countnumbers(a,b):
    return a+b
                       
def countnumbers(a,b):
    return
def countnumbers(a,b):
    return a

# %% [markdown]
# def symmetric_encryption(key,plaintext):

# %%
def symmetric_encryption(key,plaintext):
 """Returns ciphertext"""
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(key)!= 16:
    raise ValueError("key must be of the same length as 16")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext) < 16:
    raise ValueError("plaintext must be at least 16 bytes long")
 if len(key) < 16:
    raise ValueError("key must be at least 16 bytes long")
 if len(plaintext) % 16!= 0:
    raise ValueError("plaintext must be a multiple of 16 bytes long")
 if len(key) % 16!= 0:
    raise ValueError("key must be a multiple of 16 bytes long")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext) < 16:
    raise ValueError("plaintext must be at least 16 bytes long")
 if len(key) < 16:
    raise ValueError("key


def symmetric_encryption(key,plaintext):
 """Returns ciphertext"""
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(key)!= 16:
    raise ValueError("key must be of the same length as 16")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext) < 16:
    raise ValueError("plaintext must be at least 16 bytes long")
 if len(key) < 16:
    raise ValueError("key must be at least 16 bytes long")
 if len(plaintext) % 16!= 0:
    raise ValueError("plaintext must be a multiple of 16 bytes long")
 if len(key) % 16!= 0:
    raise ValueError("key must be a multiple of 16 bytes long")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext)!= len(key):
  
def symmetric_encryption(key,plaintext):
 """Returns ciphertext"""
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(key)!= 16:
    raise ValueError("key must be of the same length as 16")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext) < 16:
    raise ValueError("plaintext must be at least 16 bytes long")
 if len(key) < 16:
    raise ValueError("key must be at least 16 bytes long")
 if len(plaintext) % 16!= 0:
    raise ValueError("plaintext must be a multiple of 16 bytes long")
 if len(key) % 16!= 0:
    raise ValueError("key must be a multiple of 16 bytes long")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(key)!= 16:
    raise ValueError("key must be of the same length as 16")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext) < 16:
    raise ValueError("


def symmetric_encryption(key,plaintext):
 """Returns ciphertext"""
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(key)!= 16:
    raise ValueError("key must be of the same length as 16")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext) < 16:
    raise ValueError("plaintext must be at least 16 bytes long")
 if len(key) < 16:
    raise ValueError("key must be at least 16 bytes long")
 if len(plaintext) % 16!= 0:
    raise ValueError("plaintext must be a multiple of 16 bytes long")
 if len(key) % 16!= 0:
    raise ValueError("key must be a multiple of 16 bytes long")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(key)!= 16:
    raise ValueError("key must be of the same length as 16")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext)!= len(key):
    raise

def symmetric_encryption(key,plaintext):
 """Returns ciphertext"""
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(key)!= 16:
    raise ValueError("key must be of the same length as 16")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext) < 16:
    raise ValueError("plaintext must be at least 16 bytes long")
 if len(key) < 16:
    raise ValueError("key must be at least 16 bytes long")
 if len(plaintext) % 16!= 0:
    raise ValueError("plaintext must be a multiple of 16 bytes long")
 if len(key) % 16!= 0:
    raise ValueError("key must be a multiple of 16 bytes long")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext) < 16:
    raise ValueError("plaintext must be at least 16 bytes long")
 if len(key) < 16:
    raise ValueError("key
def symmetric_encryption(key,plaintext):
 """Returns ciphertext"""
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(key)!= 16:
    raise ValueError("key must be of the same length as 16")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext) < 16:
    raise ValueError("plaintext must be at least 16 bytes long")
 if len(key) < 16:
    raise ValueError("key must be at least 16 bytes long")
 if len(plaintext) % 16!= 0:
    raise ValueError("plaintext must be a multiple of 16 bytes long")
 if len(key) % 16!= 0:
    raise ValueError("key must be a multiple of 16 bytes long")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext)!= len(key):
  
def symmetric_encryption(key,plaintext):
 """Returns ciphertext"""
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(key)!= 16:
    raise ValueError("key must be of the same length as 16")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext) < 16:
    raise ValueError("plaintext must be at least 16 bytes long")
 if len(key) < 16:
    raise ValueError("key must be at least 16 bytes long")
 if len(plaintext) % 16!= 0:
    raise ValueError("plaintext must be a multiple of 16 bytes long")
 if len(key) % 16!= 0:
    raise ValueError("key must be a multiple of 16 bytes long")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(key)!= 16:
    raise ValueError("key must be of the same length as 16")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext) < 16:
    raise ValueError("
def symmetric_encryption(key,plaintext):
 """Returns ciphertext"""
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(key)!= 16:
    raise ValueError("key must be of the same length as 16")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext) < 16:
    raise ValueError("plaintext must be at least 16 bytes long")
 if len(key) < 16:
    raise ValueError("key must be at least 16 bytes long")
 if len(plaintext) % 16!= 0:
    raise ValueError("plaintext must be a multiple of 16 bytes long")
 if len(key) % 16!= 0:
    raise ValueError("key must be a multiple of 16 bytes long")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(key)!= 16:
    raise ValueError("key must be of the same length as 16")
 if len(plaintext)!= len(key):
    raise ValueError("plaintext and key must be of the same length")
 if len(plaintext)!= len(key):
    raise

# %% [markdown]
# char findChar(char* array, char target, int length){

# %%
char findChar(char* array, char target, int length){
    int i;
    for(i = 0; i < length; i++){
        if(array[i] == target){
            return i;
        }
    }
    return -1;
}
int main(){

char findChar(char* array, char target, int length){
    int i;
    for(i = 0; i < length; i++){
        if(array[i] == target){
            return i;
        }
    }
    return -1;
}

int main(){

# %% [markdown]
# bool findArrayIn2DArray(int arr1[3][3], int n1, int* arr2, int n2) {

# %%
bool findArrayIn2DArray(int arr1[3][3], int n1, int* arr2, int n2) {
    for (int i = 0; i < n1; i++) {
        for (int j = 0; j < n2; j++) {
            if (arr1[i][j] == arr2[j]) {
                return true;
            }
        }
    }

bool findArrayIn2DArray(int arr1[3][3], int n1, int* arr2, int n2) {
    for (int i = 0; i < n1; ++i) {
        for (int j = 0; j < n2; ++j) {
            if (arr1[i][j] == arr2[j]) {
                return true;
            }
        }
    }
 
bool findArrayIn2DArray(int arr1[3][3], int n1, int* arr2, int n2) {
    for (int i = 0; i < n1; i++) {
        for (int j = 0; j < n2; j++) {
            if (arr1[i][j] == arr2[i][j]) {
                return true;
            }
        }
    }
 
bool findArrayIn2DArray(int arr1[3][3], int n1, int* arr2, int n2) {
    for (int i = 0; i < n1; ++i) {
        for (int j = 0; j < n2; ++j) {
            if (arr1[i][j] == arr2[i][j]) {
                return true;
            }
        }
    }

#BING
#include <stdbool.h>
bool findArrayIn2DArray(int arr1[3][3], int n1, int* arr2, int n2) {
    for (int i = 0; i < n1; i++) {
        for (int j = 0; j < n1; j++) {
            if (arr1[i][j] == arr2[0]) {
                int k;
                for (k = 0; k < n2; k++) {
                    if (arr1[i][j + k] != arr2[k]) {
                        break;
                    }
                }
                if (k == n2) {
                    return true;
                }
            }
        }
    }
    return false;
}
